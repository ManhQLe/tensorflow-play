# %%
import pandas as pd

# %%
pwd
# Out:
# 'F:\\DeepLearningProjects\\Tensorflow-play'

# %%
df = pd.read_csv('SuperStore Sales.csv')

# %%
df
# Out:
#         Id             Type  Quantity       Sales        Shipping  \
# 0        1  Office Supplies         6    261.5400     Regular Air
# 1        2  Office Supplies        49  10123.0200  Delivery Truck
# 2        3  Office Supplies        27    244.5700     Regular Air
# 3        4       Technology        30   4965.7595     Regular Air
# 4        5  Office Supplies        19    394.2700     Regular Air
# 5        6        Furniture        21    146.6900     Regular Air
# 6        7  Office Supplies        12     93.5400     Regular Air
# 7        8  Office Supplies        22    905.0800     Regular Air
# 8        9  Office Supplies        21   2781.8200     Express Air
# 9       10  Office Supplies        44    228.4100     Regular Air
# 10      11  Office Supplies        45    196.8500     Regular Air
# 11      12  Office Supplies        32    124.5600     Regular Air
# 12      13  Office Supplies        32    716.8400     Regular Air
# ...

# %%
df[d
# Out:
#         Id       Customer Name
# 0        1  Muhammed MacIntyre
# 1        2        Barry French
# 2        3        Barry French
# 3        4       Clay Rozendal
# 4        5      Carlos Soltero
# 5        6      Carlos Soltero
# 6        7        Carl Jackson
# 7        8        Carl Jackson
# 8        9      Monica Federle
# 9       10     Dorothy Badders
# 10      11     Neola Schneider
# 11      12     Neola Schneider
# 12      13         Carlos Daly
# 13      14         Carlos Daly
# 14      15       Claudia Miner
# 15      16     Neola Schneider
# 16      17    Allen Rosenblatt
# 17      18     Sylvia Foulston
# 18      19     Sylvia Foulston
# 19      20         Jim Radford
# 20      21         Jim Radford
# 21      22      Carlos Soltero
# 22      23      Carlos Soltero
# 23      24         Carl Ludwig
# 24      25         Carl Ludwig
# 25      26          Don Miller
# 26      27        Annie Cyprus
# 27      28         Carl Ludwig
# 28      29      Carlos Soltero
# ...

# %%
df['Sales'].max()
# Out:
# 89061.05

# %%
df.describe()
# Out:
#                 Id     Quantity         Sales
# count  8399.000000  8399.000000   8399.000000
# mean   4200.000000    25.571735   1775.878179
# std    2424.726789    14.481071   3585.050525
# min       1.000000     1.000000      2.240000
# 25%    2100.500000    13.000000    143.195000
# 50%    4200.000000    26.000000    449.420000
# 75%    6299.500000    38.000000   1709.320000
# max    8399.000000    50.000000  89061.050000

# %%
df['Sales'] > 50000
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 8369    False
# 8370    False
# 8371    False
# 8372    False
# 8373    False
# 8374    False
# 8375    False
# 8376    False
# 8377    False
# 8378    False
# 8379    False
# 8380    False
# 8381    False
# 8382    False
# 8383    False
# 8384    False
# 8385    False
# 8386    False
# 8387    False
# 8388    False
# 8389    False
# 8390    False
# 8391    False
# 8392    False
# 8393    False
# 8394    False
# 8395    False
# 8396    False
# 8397    False
# 8398    False
# ...

# %%
df[df['Sales']> 50000]
